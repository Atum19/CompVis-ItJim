# %%
import os
import cv2
import time
import pylab
import numpy as np
import matplotlib.patches as patches
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# %%
def display_img(img):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img)

# %%
image_filename = '../images_hm_task1/hearts 4.png'
img_bgr = cv2.imread(image_filename)
img_bgr = cv2.resize(img_bgr, (img_bgr.shape[1] // 2, img_bgr.shape[0] // 2))

# %%
image = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)

# %%
# Calculate 2D Laplacian for the same image
laplacian = cv2.Laplacian(image, cv2.CV_64F)

# and do all the transformations to show the result nicely
laplacian = laplacian / np.max(laplacian) * 255
laplacian = np.uint8(laplacian)
# laplacian = cv2.cvtColor(laplacian, cv2.COLOR_GRAY2BGR)
# laplacian = cv2.putText(laplacian, 'Laplacian', (30, 30),
#                       cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2, cv2.LINE_AA)

# %%
gamma = -0.5
effected_image = np.power(laplacian, gamma)
display_img(effected_image)
# Out:
# <ipython-input-33-c2c683840452>:2: RuntimeWarning: divide by zero encountered in power
#   effected_image = np.power(laplacian, gamma)

# %%
eq_gorilla = cv2.equalizeHist(laplacian)

# %%
cv2.imshow('', eq_gorilla)
cv2.waitKey(0)
cv2.destroyWindow('')

# %%
# img_grey2 = cv2.cvtColor(laplacian, cv2.COLOR_BGR2GRAY)

# %%
img_thresh = cv2.adaptiveThreshold(laplacian, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 55, 2)

# %%
cv2.imshow('', img_thresh)
cv2.waitKey(0)
cv2.destroyWindow('')

# %%
# Conversion of the image into another color space
img_gray = cv2.cvtColor(im_hf, cv2.COLOR_BGR2GRAY)

# %%
# Add text and show the initial image
im_to_show = img_gray.copy()
im_to_show = cv2.putText(im_to_show, 'Initial image', (50, 50),
                      cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
cv2.imshow('', im_to_show)
cv2.waitKey(0)
cv2.destroyWindow('')

# %%
img_thresh = cv2.adaptiveThreshold(img_gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 55, 5)

# %%
cv2.imshow('', img_thresh)
cv2.waitKey(0)
cv2.destroyWindow('')
